# %%
from custom_functions import *

# %%
dsa_accme_df = pd.read_csv('./data/spa_stacks/dsa_conv_accme_parameters.csv')
dsa_accme_df = generate_accme_cycles_column(dsa_accme_df)

# %%
# config_choice 1-55, to choose desired image/kernel size.
# bus_width 1-anything, number of bytes the memory system can supply each cycle 
plot_spa_stacks(df=dsa_accme_df, bus_width=8, config_choice=17)
# Out:
# [61440.0, 1.0, 13.5]
# [15360.0, 1.0, 51.0]
# [3840.0, 8452.125, 201.0]
# [960.0, 11332.125, 801.0]
